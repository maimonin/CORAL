# %% [markdown]
# # Imports

# %%
import pandas as pd
import json
from tqdm import tqdm

# %% [markdown]
# # Provenance Data

# %% [markdown]
# ## Load original logs

# %%
# Provenance data paths
artifacts_vertices_path = "../provenance_data/app_artifact_vertices.csv"
processes_vertices_path = "../provenance_data/app_process_vertices.csv"
edges_path = "../provenance_data/app_edges.csv"

# %%
# Load provenance data to dataframes
artifacts_df = pd.read_csv(artifacts_vertices_path, index_col=0)
processes_df = pd.read_csv(processes_vertices_path, index_col=0)
edges_df = pd.read_csv(edges_path, index_col=0)

# %% [markdown]
# ## Add generated attack simulation logs

# %%
generated_artifacts_path = "attack_scenario123_gen_artifacts.csv"
generated_processes_path = "attack_scenario123_gen_processes.csv"
generated_edges_path = "attack_scenario123_gen_edges.csv"

# %%
generated_artifacts_df = pd.read_csv(generated_artifacts_path)
generated_processes_df = pd.read_csv(generated_processes_path)
generated_edges_df = pd.read_csv(generated_edges_path)

# %%
artifacts_df = pd.concat([artifacts_df, generated_artifacts_df], ignore_index=True)

# %%
# Get the common columns between the two dataframes
common_columns = processes_df.columns.intersection(generated_processes_df.columns)

# Select only the common columns from both dataframes
processes_df = processes_df[common_columns]
generated_processes_df = generated_processes_df[common_columns]

# Now you can concatenate
processes_df = pd.concat([processes_df, generated_processes_df], ignore_index=True)

processes_df
# Out:
#                                     id     type   gid  euid  \
# 0     0ef366a12c22d68dcc35e410ab69719e  Process  1000  1000
# 1     3f921fd1ce1cc790417d2071cc0a3c34  Process  1000  1000
# 2     e6103611b0969dad371a1d6e665772e7  Process  1000  1000
# 3     ff8a80868c60e4a5a1503a31124cd340  Process  1000  1000
# 4     b6acb3e5c8618efc89e85cd9e2ee9823  Process  1000  1000
# ..                                 ...      ...   ...   ...
# 504   7a8b9c0d1e2f3a4b5c6d7e8f9a0b1c2d  Process  1000  1000
# 505   8f9a0b1c2d3e4f5a6b7c8d9e0a1b2c3d  Process     0     0
# 506   9a0b1c2d3e4f5a6b7c8d9e0a1b2c3d4e  Process     0     0
# 507  a0b1c2d3e4f5a6b7c8d9e0a1b2c3d4e5f  Process     0     0
# 508  b1c2d3e4f5a6b7c8d9e0a1b2c3d4e5f6a  Process     0     0
#
#      children pid namespace     pid     seen time                 source  \
# 0             -1.000000e+00  1711.0           NaN                syscall
# 1              4.026533e+09  1723.0           NaN                syscall
# 2              4.026533e+09  1724.0           NaN                syscall
# 3              4.026533e+09  1725.0           NaN                syscall
# 4              4.026533e+09  1726.0           NaN                syscall
# ..                      ...     ...           ...                    ...
# 504           -1.000000e+00  1725.0  1.681923e+09  recommendationservice
# 505           -1.000000e+00  9877.0  1.681924e+09               frontend
# 506           -1.000000e+00  9879.0  1.681924e+09  recommendationservice
# 507           -1.000000e+00  9880.0  1.681924e+09  recommendationservice
# 508           -1.000000e+00  9881.0  1.681924e+09  recommendationservice
#
#      net namespace  ipc namespace  ...   uid  egid                     exe  \
# 0    -1.000000e+00  -1.000000e+00  ...  1000  1000  /bin/grpc_health_probe
# 1     4.026532e+09   4.026533e+09  ...  1000  1000  /bin/grpc_health_probe
# 2     4.026532e+09   4.026533e+09  ...  1000  1000  /bin/grpc_health_probe
# 3     4.026532e+09   4.026533e+09  ...  1000  1000  /bin/grpc_health_probe
# 4     4.026532e+09   4.026533e+09  ...  1000  1000  /bin/grpc_health_probe
# ..             ...            ...  ...   ...   ...                     ...
# 504   4.026532e+09   4.026532e+09  ...  1000  1000                 /bin/sh
# 505   4.026532e+09   4.026532e+09  ...     0     0           /usr/bin/sudo
# 506   4.026532e+09   4.026532e+09  ...     0     0                     NaN
# 507   4.026532e+09   4.026532e+09  ...     0     0                     NaN
# 508   4.026532e+09   4.026532e+09  ...     0     0               /bin/bash
#
#      mount namespace             name user namespace    start time  \
# 0      -1.000000e+00  grpc_health_pro  -1.000000e+00  1.702120e+09
# 1       4.026533e+09  grpc_health_pro   4.026532e+09  1.702120e+09
# 2       4.026533e+09  grpc_health_pro   4.026532e+09  1.702120e+09
# 3       4.026533e+09  grpc_health_pro   4.026532e+09  1.702120e+09
# 4       4.026533e+09  grpc_health_pro   4.026532e+09  1.702120e+09
# ..               ...              ...            ...           ...
# 504     4.026532e+09               sh   4.026532e+09  1.681923e+09
# 505     4.026532e+09             sudo   4.026532e+09  1.681924e+09
# 506     4.026532e+09          python3   4.026532e+09  1.681924e+09
# 507     4.026532e+09          python3   4.026532e+09  1.681924e+09
# 508     4.026532e+09             bash   4.026532e+09  1.681924e+09
#
#                                           command line  ns pid  \
# 0                   /bin/grpc_health_probe -addr=:8080     NaN
# 1                   /bin/grpc_health_probe -addr=:8080  2489.0
# 2                   /bin/grpc_health_probe -addr=:8080  2490.0
# 3                   /bin/grpc_health_probe -addr=:8080  2491.0
# 4                   /bin/grpc_health_probe -addr=:8080  2492.0
# ..                                                 ...     ...
# 504  /bin/sh -c /usr/sbin/tcpdump -i eth0 -w /tmp/r...     NaN
# 505                    /usr/bin/sudo -u root /bin/bash     NaN
# 506     /usr/bin/python3 /app/recommendation_server.py     NaN
# 507   /usr/bin/python3 /tmp/deserialization_exploit.py     NaN
# 508                                          /bin/bash     NaN
#
#                        svc
# 0                 frontend
# 1                 frontend
# 2                 frontend
# 3                 frontend
# 4                 frontend
# ..                     ...
# 504  recommendationservice
# 505               frontend
# 506  recommendationservice
# 507  recommendationservice
# 508  recommendationservice
#
# [509 rows x 23 columns]

# %%
# Concat the edges dataframes without 'svc_from' and 'svc_to' columns
edges_df = pd.concat([edges_df, generated_edges_df.drop(columns=['svc_from', 'svc_to'])], ignore_index=True)

# %% [markdown]
# ## Save updated provenance data

# %%
# Save the updated provenance data
artifacts_df.to_csv('artifacts_with_generated.csv', index=True)
processes_df.to_csv('processes_with_generated.csv', index=True)
edges_df.to_csv('edges_with_generated.csv', index=True)

# %% [markdown]
# # Alerts Mechanism - CHECK MATCHES

# %%
sigma_rules_values_path = "../alerts_mechanism/sigma_rules_values_with_names.json"

with open(sigma_rules_values_path, 'r') as f:
    sigma_rules_values_with_names = json.load(f)

# %%
artifacts_matches = []

for index, row in tqdm(artifacts_df.iterrows(), total=len(artifacts_df)):
    for column, value in row.items():
        if value in list(sigma_rules_values_with_names.keys()) and value not in artifacts_matches:
            artifacts_matches.append(value)
                
artifacts_matches
# Out:
# 100%|██████████| 1591/1591 [00:29<00:00, 54.80it/s]
# ['0.0.0.0', 'tcp', '127.0.0.1', 'udp', '/etc/sudoers']

# %%
processes_matches = []

for index, row in tqdm(processes_df.iterrows(), total=len(processes_df)):
    for column, value in row.items():
        if value in list(sigma_rules_values_with_names.keys()) and value not in processes_matches:
            processes_matches.append(value)
                
processes_matches
# Out:
# 100%|██████████| 509/509 [00:09<00:00, 53.36it/s]
# ['Process', '/bin/sh', 'sh', 'sudo', '/bin/bash', 'bash']

# %%
edges_matches = []

for index, row in tqdm(edges_df.iterrows(), total=len(edges_df)):
    for column, value in row.items():
        if value in list(sigma_rules_values_with_names.keys()) and value not in edges_matches:
            edges_matches.append(value)
                
edges_matches
# Out:
# 100%|██████████| 2585/2585 [00:21<00:00, 117.91it/s]
# ['accept', 'execve', 'open', 'connect']

# %%
# Initialize the list to store matches
artifacts_matches = []

# Iterate over the dataframe
for index, row in tqdm(artifacts_df.iterrows(), total=len(artifacts_df)):
    for column, value in row.items():
        # Check if the value is in the keys of the sigma_rules_values_with_names dictionary
        if value in sigma_rules_values_with_names.keys():
            # If a match is found, create a dictionary with the matched value, the dataframe row, and the associated rule
            match = {
                'matched_value': value,
                'dataframe_row': row.to_dict(),
                'associated_rule': sigma_rules_values_with_names[value]
            }
            # Append the match to the list of matches
            artifacts_matches.append(match)

# Print the matches
artifacts_matches
# Out:
# 100%|██████████| 1591/1591 [00:00<00:00, 18932.66it/s]
# [{'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': 'a41db92088a31a823a23ed48145dd661',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 39612.0,
#    'protocol': 'tcp',
#    'remote address': '172.31.30.227',
#    'local port': 6379.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'redis-cart'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'a41db92088a31a823a23ed48145dd661',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 39612.0,
#    'protocol': 'tcp',
#    'remote address': '172.31.30.227',
#    'local port': 6379.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'redis-cart'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': 'a2f50c6b069415c603efdac935d00de4',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 39614.0,
#    'protocol': 'tcp',
#    'remote address': '172.31.30.227',
#    'local port': 6379.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'redis-cart'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'a2f50c6b069415c603efdac935d00de4',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 39614.0,
#    'protocol': 'tcp',
#    'remote address': '172.31.30.227',
#    'local port': 6379.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'redis-cart'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': 'be892937315bea0644510e695d37ac30',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46636.0,
#    'net namespace': 4026532231.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'be892937315bea0644510e695d37ac30',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46636.0,
#    'net namespace': 4026532231.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': 'be892937315bea0644510e695d37ac30',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46636.0,
#    'net namespace': 4026532231.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '5a7a49b0a1c2096d4e6e896d35f9194d',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 46636.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 8080.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '80a3b6046c1aa2dda29b76dc32d1e4fa',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46642.0,
#    'net namespace': 4026532231.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '80a3b6046c1aa2dda29b76dc32d1e4fa',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46642.0,
#    'net namespace': 4026532231.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '80a3b6046c1aa2dda29b76dc32d1e4fa',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46642.0,
#    'net namespace': 4026532231.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'cf367aec66d57a49adcb74b784437e1f',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 46642.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 8080.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'a89c134c210562dfccc3bea41c2d5d63',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 36032.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 50051.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '8df23791c8b2af5a86b875d28afdcc51',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36032.0,
#    'net namespace': 4026532967.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '8df23791c8b2af5a86b875d28afdcc51',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36032.0,
#    'net namespace': 4026532967.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '8df23791c8b2af5a86b875d28afdcc51',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36032.0,
#    'net namespace': 4026532967.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'e7026795986d1db96f7ca019fe9aca94',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 46658.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 8080.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': 'f6afa0dc808e7927692a2a402dd37e1b',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46658.0,
#    'net namespace': 4026532694.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'f6afa0dc808e7927692a2a402dd37e1b',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46658.0,
#    'net namespace': 4026532694.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': 'f6afa0dc808e7927692a2a402dd37e1b',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46658.0,
#    'net namespace': 4026532694.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '5ac5d0a9cea066d03b805a8a1e419e54',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46664.0,
#    'net namespace': 4026532694.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '5ac5d0a9cea066d03b805a8a1e419e54',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46664.0,
#    'net namespace': 4026532694.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '5ac5d0a9cea066d03b805a8a1e419e54',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46664.0,
#    'net namespace': 4026532694.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'b19587f0ce057e0a68dedb9f2a76026e',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 46664.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 8080.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'df651caf48a8fb66322f4d4f0a0887ae',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 55840.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:AC1F:1EE3',
#    'local port': 8080.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '7baa97ff0494788f0b47200ef6aaa6a8',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36038.0,
#    'net namespace': 4026532382.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '7baa97ff0494788f0b47200ef6aaa6a8',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36038.0,
#    'net namespace': 4026532382.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '7baa97ff0494788f0b47200ef6aaa6a8',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36038.0,
#    'net namespace': 4026532382.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '69824c109ae4302f910be7a9e823d71c',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 36038.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 50051.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': 'a14668ae49f6ee8b6355891156206d37',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7070.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 55102.0,
#    'net namespace': 4026532899.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'cartservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'a14668ae49f6ee8b6355891156206d37',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7070.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 55102.0,
#    'net namespace': 4026532899.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'cartservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': 'a14668ae49f6ee8b6355891156206d37',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7070.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 55102.0,
#    'net namespace': 4026532899.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'cartservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '87ae26cb62fd1b3481c32d1e4f60a4ba',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 55102.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 7070.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'cartservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'd5e6ecbfd578d56a4fd2a52574557af2',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 55844.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:AC1F:1EE3',
#    'local port': 8080.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '703a57eb0eaf1afe71b4b4ae39f694c6',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 43688.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 7000.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '465862b6f8b03b3e88e9cb462132dced',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7000.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 43688.0,
#    'net namespace': 4026532583.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '465862b6f8b03b3e88e9cb462132dced',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7000.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 43688.0,
#    'net namespace': 4026532583.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '465862b6f8b03b3e88e9cb462132dced',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7000.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 43688.0,
#    'net namespace': 4026532583.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '088dabc017ff04ffbfe67a32b98e8944',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36046.0,
#    'net namespace': 4026532382.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '088dabc017ff04ffbfe67a32b98e8944',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36046.0,
#    'net namespace': 4026532382.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '088dabc017ff04ffbfe67a32b98e8944',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36046.0,
#    'net namespace': 4026532382.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'fb507055b141b3fd37433c97e4cf05cb',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 36046.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 50051.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '90dd4bea017d4880ad69f8b359bd601f',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 3550.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 34350.0,
#    'net namespace': 4026532449.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '90dd4bea017d4880ad69f8b359bd601f',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 3550.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 34350.0,
#    'net namespace': 4026532449.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '90dd4bea017d4880ad69f8b359bd601f',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 3550.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 34350.0,
#    'net namespace': 4026532449.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'd5a7e866af60ad8ea6677f6d8309b1ed',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 34350.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 3550.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '29a8df94fc46d2ae387d5d2ae0d668dc',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7070.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 55106.0,
#    'net namespace': 4026532899.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'cartservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '29a8df94fc46d2ae387d5d2ae0d668dc',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7070.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 55106.0,
#    'net namespace': 4026532899.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'cartservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '29a8df94fc46d2ae387d5d2ae0d668dc',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7070.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 55106.0,
#    'net namespace': 4026532899.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'cartservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '8f81ec5123339f726e81185572c9074c',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 55106.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 7070.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'cartservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '8f73a750905117f3f45810eea79c923e',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 3550.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 34356.0,
#    'net namespace': 4026532449.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '8f73a750905117f3f45810eea79c923e',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 3550.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 34356.0,
#    'net namespace': 4026532449.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '8f73a750905117f3f45810eea79c923e',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 3550.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 34356.0,
#    'net namespace': 4026532449.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '7428adc6445392a6eb8066a7f3d9f3ec',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 34356.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 3550.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '0b0919bd7c3db979f75592d01b508f61',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7000.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 43704.0,
#    'net namespace': 4026532583.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '0b0919bd7c3db979f75592d01b508f61',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7000.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 43704.0,
#    'net namespace': 4026532583.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '0b0919bd7c3db979f75592d01b508f61',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7000.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 43704.0,
#    'net namespace': 4026532583.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '0d5dc426db6fba38aa2fad35c45e81fc',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 43704.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 7000.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': 'bcebe7b8dd2fe889e103dfa10d77edc6',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36050.0,
#    'net namespace': 4026532967.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'bcebe7b8dd2fe889e103dfa10d77edc6',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36050.0,
#    'net namespace': 4026532967.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': 'bcebe7b8dd2fe889e103dfa10d77edc6',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 36050.0,
#    'net namespace': 4026532967.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '7bc945978b4aadfe4d7f2f75f0ec7886',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 36050.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 50051.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '90bc64de35e356de6d7062ed712606c7',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 39636.0,
#    'protocol': 'tcp',
#    'remote address': '172.31.30.227',
#    'local port': 6379.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'redis-cart'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '90bc64de35e356de6d7062ed712606c7',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 39636.0,
#    'protocol': 'tcp',
#    'remote address': '172.31.30.227',
#    'local port': 6379.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'redis-cart'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '6923e0d2e16ac5e3b77b516c69990235',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 39638.0,
#    'protocol': 'tcp',
#    'remote address': '172.31.30.227',
#    'local port': 6379.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'redis-cart'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '6923e0d2e16ac5e3b77b516c69990235',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 39638.0,
#    'protocol': 'tcp',
#    'remote address': '172.31.30.227',
#    'local port': 6379.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'redis-cart'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '773c68c3b89710892a4783d58c60923e',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 8080.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 46678.0,
#    'net namespace': 4026532231.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '773c68c3b89710892a4783d58c60923e',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
# ...
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '9b785b5a5d2dc461a9fca8e7e959fed0',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7070.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 49254.0,
#    'net namespace': 4026532899.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'cartservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '9b785b5a5d2dc461a9fca8e7e959fed0',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7070.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 49254.0,
#    'net namespace': 4026532899.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'cartservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '3bd046e5f56c015ac67a439a70bb93b9',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 49254.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 7070.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'cartservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '44593fa4d9a1562de7a6c9d5cc888d70',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 35064.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:AC1F:1EE3',
#    'local port': 8080.0,
#    'net namespace': 4026532830.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '40bd8feab58f3d49ce3f674c5c90346b',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 35042.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 7000.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '3998eceda38b8f5dae8cc3bae8bf54e0',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7000.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 35042.0,
#    'net namespace': 4026532583.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '3998eceda38b8f5dae8cc3bae8bf54e0',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7000.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 35042.0,
#    'net namespace': 4026532583.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '3998eceda38b8f5dae8cc3bae8bf54e0',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 7000.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 35042.0,
#    'net namespace': 4026532583.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'currencyservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '21b987534f7bbaa103be947ab2d950ad',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 43390.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 3550.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '5238236d70966fe2bda3eb36fbe49df9',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 3550.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 43390.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '5238236d70966fe2bda3eb36fbe49df9',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 3550.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 43390.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '5238236d70966fe2bda3eb36fbe49df9',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 3550.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 43390.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'productcatalogservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': '58fec781896a518ed3adf046ed9e8548',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 37622.0,
#    'net namespace': 4026532382.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '58fec781896a518ed3adf046ed9e8548',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 37622.0,
#    'net namespace': 4026532382.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': '58fec781896a518ed3adf046ed9e8548',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '127.0.0.1',
#    'remote port': 50051.0,
#    'protocol': 'tcp',
#    'remote address': '0.0.0.0',
#    'local port': 37622.0,
#    'net namespace': 4026532382.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'cd9b49dcd834bd4771719cbffbf5370e',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0000:0000:0000:0000:0000:0000:0000:0000',
#    'remote port': 37622.0,
#    'protocol': 'tcp',
#    'remote address': '0000:0000:0000:0000:0000:FFFF:7F00:0001',
#    'local port': 50051.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'paymentservice'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': '4687fe9021e5b8d3c7ac4fe3d1e89f6a',
#    'type': 'Artifact',
#    'path': '/tmp/payload',
#    'subtype': 'file',
#    'permissions': 644.0,
#    'epoch': 1681921228.0,
#    'source': 'external',
#    'version': 1,
#    'local address': nan,
#    'remote port': nan,
#    'protocol': 'tcp',
#    'remote address': '142.23.45.67',
#    'local port': 54321.0,
#    'net namespace': 4026532277.0,
#    'memory address': '0x7ffc123456',
#    'size': 4096.0,
#    'tgid': 1234.0,
#    'read fd': 3.0,
#    'write fd': 4.0,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': 'ecdff5c9b6f4c964746829e513ac3e01',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 54321.0,
#    'protocol': 'tcp',
#    'remote address': '142.23.45.67',
#    'local port': 80.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'ecdff5c9b6f4c964746829e513ac3e01',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 54321.0,
#    'protocol': 'tcp',
#    'remote address': '142.23.45.67',
#    'local port': 80.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '0.0.0.0',
#   'dataframe_row': {'id': 'f92d146f15e06f2ea4d0bc9aaa788b6b',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 57236.0,
#    'protocol': 'tcp',
#    'remote address': '127.0.0.1',
#    'local port': 8080.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': 'tcp',
#   'dataframe_row': {'id': 'f92d146f15e06f2ea4d0bc9aaa788b6b',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 57236.0,
#    'protocol': 'tcp',
#    'remote address': '127.0.0.1',
#    'local port': 8080.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_win_susp_epmap.yml']},
#  {'matched_value': '127.0.0.1',
#   'dataframe_row': {'id': 'f92d146f15e06f2ea4d0bc9aaa788b6b',
#    'type': 'Artifact',
#    'path': nan,
#    'subtype': 'network socket',
#    'permissions': nan,
#    'epoch': 0.0,
#    'source': 'syscall',
#    'version': 0,
#    'local address': '0.0.0.0',
#    'remote port': 57236.0,
#    'protocol': 'tcp',
#    'remote address': '127.0.0.1',
#    'local port': 8080.0,
#    'net namespace': -1.0,
#    'memory address': nan,
#    'size': nan,
#    'tgid': nan,
#    'read fd': nan,
#    'write fd': nan,
#    'svc': 'frontend'},
#   'associated_rule': ['net_connection_lnx_back_connect_shell_dev.yml',
#    'win_security_susp_rottenpotato.yml',
#    'net_connection_win_remote_powershell_session_network.yml',
#    'win_security_susp_krbrelayup.yml',
#    'net_connection_win_python.yml',
#    'win_security_rdp_localhost_login.yml',
#    'net_connection_win_powershell_network_connection.yml',
#    'net_connection_win_excel_outbound_network_connection.yml',
#    'zeek_dns_mining_pools.yml']},
#  {'matched_value': '/etc/sudoers',
#   'dataframe_row': {'id': '4b5c6d7e8f9a0b1c2d3e4f5a6b7c8d9e',
#    'type': 'Artifact',
#    'path': '/etc/sudoers',
#    'subtype': 'file',
#    'permissions': 440.0,
#    'epoch': 1681924000.0,
#    'source': 'frontend',
#    'version': 1,
#    'local address': nan,
#    'remote port': nan,
#    'protocol': nan,
#    'remote address': nan,
#    'local port': nan,
#    'net namespace': 4026532277.0,
#    'memory address': nan,
#    'size': 4096.0,
#    'tgid': 9877.0,
#    'read fd': nan,
#    'write fd': 12.0,
#    'svc': 'frontend'},
#   'associated_rule': ['proc_creation_lnx_susp_sensitive_file_access.yml',
#    'proc_creation_macos_local_account.yml',
#    'proc_creation_lnx_local_account.yml']}]

# %%
# Initialize the list to store matches
processes_matches = []

# Iterate over the dataframe
for index, row in tqdm(processes_df.iterrows(), total=len(processes_df)):
    for column, value in row.items():
        # Check if the value is in the keys of the sigma_rules_values_with_names dictionary
        if value in sigma_rules_values_with_names.keys():
            # If a match is found, create a dictionary with the matched value, the dataframe row, and the associated rule
            match = {
                'matched_value': value,
                'dataframe_row': row.to_dict(),
                'associated_rule': sigma_rules_values_with_names[value]
            }
            # Append the match to the list of matches
            processes_matches.append(match)

# Print the matches
for match in processes_matches:
    print(match['matched_value'])
# Out:
# 100%|██████████| 509/509 [00:00<00:00, 12109.41it/s]
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# Process
# /bin/sh
# sh
# Process
# sudo
# Process
# Process
# Process
# /bin/bash
# bash
# /bin/bash

# %%
# Initialize the list to store matches
edges_matches = []

# Iterate over the dataframe
for index, row in tqdm(edges_df.iterrows(), total=len(edges_df)):
    for column, value in row.items():
        # Check if the value is in the keys of the sigma_rules_values_with_names dictionary
        if value in sigma_rules_values_with_names.keys():
            # If a match is found, create a dictionary with the matched value, the dataframe row, and the associated rule
            match = {
                'matched_value': value,
                'dataframe_row': row.to_dict(),
                'associated_rule': sigma_rules_values_with_names[value]
            }
            # Append the match to the list of matches
            edges_matches.append(match)

# Print the matches
for match in edges_matches:
    print(match['matched_value'])
# Out:
# 100%|██████████| 2585/2585 [00:00<00:00, 20676.21it/s]
# accept
# accept
# execve
# open
# open
# execve
# open
# open
# open
# open
# connect
# accept
# connect
# accept
# execve
# open
# open
# execve
# open
# open
# accept
# connect
# open
# execve
# accept
# open
# connect
# open
# open
# connect
# accept
# accept
# execve
# open
# open
# connect
# accept
# execve
# open
# open
# connect
# accept
# accept
# execve
# open
# open
# accept
# connect
# execve
# open
# open
# connect
# accept
# execve
# open
# open
# connect
# accept
# execve
# open
# open
# connect
# accept
# execve
# open
# open
# connect
# accept
# execve
# open
# open
# connect
# accept
# execve
# open
# open
# connect
# accept
# accept
# accept
# execve
# open
# open
# open
# connect
# accept
# execve
# open
# open
# open
# connect
# accept
# accept
# connect
# accept
# connect
# execve
# open
# execve
# open
# open
# accept
# connect
# execve
# open
# open
# accept
# connect
# execve
# open
# open
# connect
# accept
# accept
# accept
# execve
# open
# execve
# open
# open
# open
# connect
# accept
# open
# open
# connect
# accept
# execve
# open
# open
# execve
# open
# open
# accept
# accept
# connect
# accept
# execve
# open
# open
# execve
# open
# connect
# open
# connect
# accept
# connect
# accept
# execve
# open
# open
# open
# accept
# connect
# execve
# open
# open
# connect
# accept
# accept
# accept
# execve
# open
# execve
# execve
# open
# open
# open
# open
# open
# accept
# connect
# connect
# accept
# accept
# connect
# accept
# execve
# open
# open
# connect
# accept
# execve
# open
# open
# accept
# connect
# execve
# open
# open
# accept
# connect
# accept
# connect
# accept
# accept
# execve
# open
# open
# execve
# open
# open
# connect
# accept
# open
# open
# accept
# connect
# execve
# open
# execve
# open
# open
# execve
# open
# open
# accept
# connect
# accept
# connect
# execve
# open
# open
# open
# open
# connect
# accept
# connect
# open
# accept
# connect
# execve
# open
# open
# accept
# connect
# accept
# accept
# execve
# open
# execve
# open
# open
# open
# open
# connect
# accept
# open
# connect
# accept
# execve
# open
# open
# execve
# open
# open
# open
# connect
# accept
# execve
# open
# execve
# open
# open
# connect
# accept
# execve
# open
# open
# connect
# accept
# accept
# execve
# open
# execve
# open
# open
# open
# connect
# connect
# accept
# accept
# accept
# connect
# execve
# open
# open
# accept
# connect
# execve
# open
# open
# connect
# execve
# open
# open
# connect
# accept
# execve
# open
# open
# connect
# accept
# execve
# open
# open
# accept
# connect
# accept
# accept
# execve
# open
# execve
# open
# open
# open
# connect
# accept
# accept
# execve
# open
# open
# accept
# connect
# execve
# open
# open
# execve
# accept
# connect
# open
# execve
# open
# open
# open
# accept
# open
# connect
# open
# connect
# accept
# execve
# open
# open
# accept
# connect
# connect
# accept
# accept
# accept
# connect
# execve
# open
# open
# open
# connect
# accept
# accept
# accept
# connect
# execve
# open
# open
# open
# connect
# accept
# execve
# open
# open
# open
# connect
# accept
# accept
# execve
# open
# execve
# open
# open
# connect
# accept
# accept
# execve
# open
# open
# accept
# connect
# execve
# open
# accept
# connect
# execve
# open
# open
# connect
# accept
# connect

# %%
# Extract list of rule that were matched
artifacts_matched_rules = [match['associated_rule'] for match in artifacts_matches]
processes_matched_rules = [match['associated_rule'] for match in processes_matches]
edges_matched_rules = [match['associated_rule'] for match in edges_matches]

# Flatten the lists
artifacts_matched_rules = [rule for sublist in artifacts_matched_rules for rule in sublist]
processes_matched_rules = [rule for sublist in processes_matched_rules for rule in sublist]
edges_matched_rules = [rule for sublist in edges_matched_rules for rule in sublist]

# %%
# Create set of all matched rules
matched_rules = set(artifacts_matched_rules + processes_matched_rules + edges_matched_rules)
matched_rules
# Out:
# {'lnx_auditd_data_compressed.yml',
#  'lnx_auditd_masquerading_crond.yml',
#  'lnx_auditd_network_sniffing.yml',
#  'lnx_auditd_omigod_scx_runasprovider_executeshellcommand.yml',
#  'lnx_auditd_susp_cmds.yml',
#  'lnx_auditd_web_rce.yml',
#  'lnx_sudo_cve_2019_14287_user.yml',
#  'net_connection_lnx_back_connect_shell_dev.yml',
#  'net_connection_win_excel_outbound_network_connection.yml',
#  'net_connection_win_powershell_network_connection.yml',
#  'net_connection_win_python.yml',
#  'net_connection_win_rdp_outbound_over_non_standard_tools.yml',
#  'net_connection_win_remote_powershell_session_network.yml',
#  'net_connection_win_susp_epmap.yml',
#  'net_firewall_cleartext_protocols.yml',
#  'proc_creation_lnx_cve_2022_26134_atlassian_confluence.yml',
#  'proc_creation_lnx_gtfobin_vim.yml',
#  'proc_creation_lnx_local_account.yml',
#  'proc_creation_lnx_netcat_reverse_shell.yml',
#  'proc_creation_lnx_omigod_scx_runasprovider_executeshellcommand.yml',
#  'proc_creation_lnx_perl_reverse_shell.yml',
#  'proc_creation_lnx_php_reverse_shell.yml',
#  'proc_creation_lnx_susp_java_children.yml',
#  'proc_creation_lnx_susp_sensitive_file_access.yml',
#  'proc_creation_macos_local_account.yml',
#  'proc_creation_win_bash_file_execution.yml',
#  'win_security_lsass_access_non_system_account.yml',
#  'win_security_rdp_localhost_login.yml',
#  'win_security_susp_krbrelayup.yml',
#  'win_security_susp_rottenpotato.yml',
#  'zeek_dns_mining_pools.yml'}
